# %%
import numpy as np
import pandas as pd
from sklearn import neighbors, datasets
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
# carregando os dados com numpy
train = pd.read_csv('fitbit.data')
test = pd.read_csv('fitbit.data')
dados = pd.read_csv('fitbit.data', delimiter=',', usecols=(1,2,3))
entradas = pd.read_csv('fitbit.data', delimiter=',', usecols=(1,2))
saidas = np.genfromtxt('fitbit.data', delimiter=',', usecols=(3))
print(len(entradas))
print(len(saidas))
# Out:
# 404
# 405

# %% [markdown]
# # DADOS DE ENTRADA DO FITBIT

# %%
entradas = entradas.rename({"85": "batimentos", "22": "calorias"}, axis="columns")
dados = dados.rename({"85": "Batimentos", "22": "Calorias", "0.1": "Pressão Arterial"}, axis="columns")

# %% [markdown]
# # DADOS DE SAIDAS DO FITBIT

# %%
x = dados["Pressão Arterial"]
a1 =[]
y = x.size
i = 0
for i in range( 404 ):
    if x[i] == 0:
        n = "normal"
        a1.append(n)
    elif x[i] == 1:
        n = "alta"
        a1.append(n)
    elif x[i] == 2:
        n = "baixa"
        a1.append(n)

# %%
dados['Legenda'] = a1
dados
# Out:
#      Batimentos  Calorias  Pressão Arterial Legenda
# 0            86        34                 0  normal
# 1            93        34                 0  normal
# 2            92        13                 0  normal
# 3            94        12                 0  normal
# 4            87        12                 0  normal
# 5            88        12                 0  normal
# 6            80        10                 0  normal
# 7            84        10                 0  normal
# 8            70        11                 0  normal
# 9            63        11                 0  normal
# 10           66        11                 0  normal
# 11           69        11                 0  normal
# 12           69        11                 0  normal
# 13           70        10                 0  normal
# 14           82        13                 0  normal
# 15           84        13                 0  normal
# 16           86        13                 0  normal
# 17           82        13                 0  normal
# 18           82        13                 0  normal
# 19           85        13                 0  normal
# 20           78        12                 0  normal
# 21           75        12                 0  normal
# 22           75        12                 0  normal
# 23           78        12                 0  normal
# 24           87        12                 0  normal
# 25           85        13                 0  normal
# 26           89        12                 0  normal
# 27           86        12                 0  normal
# 28           79        13                 0  normal
# 29           83        13                 0  normal
# ..          ...       ...               ...     ...
# 374          95        10                 2   baixa
# 375          99        13                 2   baixa
# 376         101        13                 2   baixa
# 377         101        12                 2   baixa
# 378         102        13                 2   baixa
# 379         105        12                 2   baixa
# 380         100        12                 2   baixa
# 381          93        10                 2   baixa
# 382          93        11                 2   baixa
# 383          98        11                 2   baixa
# 384          97        10                 2   baixa
# 385          98        11                 2   baixa
# 386          96        10                 2   baixa
# 387         100        13                 2   baixa
# 388         102        12                 2   baixa
# 389         100        13                 2   baixa
# 390          98        11                 2   baixa
# 391          95        10                 2   baixa
# 392          96        10                 2   baixa
# 393          95        11                 2   baixa
# 394          94        10                 2   baixa
# 395          99        13                 2   baixa
# 396          99        13                 2   baixa
# 397          95        10                 2   baixa
# 398          95        10                 2   baixa
# 399          99        26                 2   baixa
# 400         100        13                 2   baixa
# 401         103        13                 2   baixa
# 402         104        26                 2   baixa
# 403         105        11                 2   baixa
#
# [404 rows x 4 columns]

# %% [markdown]
# # DEFININDO OS VIZINHOS NO KNN
# # TREINANDO MEU MODELO KNN|

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=3)
knn.fit(entradas[0:404], saidas[:404])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %% [markdown]
# # SAÍDAS DOS RESULTADOS DO KNN

# %%
x = knn.predict(entradas)
a = []
y = x.size
i = 0
for i in range( 404 ):
    if x[i] == 0:
        n = "normal"
        a.append(n)
    elif x[i] == 1:
        n = "alta"
        a.append(n)
    elif x[i] == 2:
        n = "baixa"
        a.append(n)

# %% [markdown]
# # ACURACIA DOS RESULTADOS

# %%
acuracia = knn.score(entradas[:404], saidas[:404])
acuracia
# Out:
# 0.8787128712871287

# %% [markdown]
# #  87.9% de certeza.

# %%
dados['knn Resultado 01'] = a
dados
# Out:
#      Batimentos  Calorias  Pressão Arterial Legenda knn Resultado 01
# 0            86        34                 0  normal           normal
# 1            93        34                 0  normal           normal
# 2            92        13                 0  normal           normal
# 3            94        12                 0  normal             alta
# 4            87        12                 0  normal           normal
# 5            88        12                 0  normal           normal
# 6            80        10                 0  normal           normal
# 7            84        10                 0  normal           normal
# 8            70        11                 0  normal           normal
# 9            63        11                 0  normal           normal
# 10           66        11                 0  normal           normal
# 11           69        11                 0  normal           normal
# 12           69        11                 0  normal           normal
# 13           70        10                 0  normal           normal
# 14           82        13                 0  normal           normal
# 15           84        13                 0  normal           normal
# 16           86        13                 0  normal           normal
# 17           82        13                 0  normal           normal
# 18           82        13                 0  normal           normal
# 19           85        13                 0  normal           normal
# 20           78        12                 0  normal           normal
# 21           75        12                 0  normal           normal
# 22           75        12                 0  normal           normal
# 23           78        12                 0  normal           normal
# 24           87        12                 0  normal           normal
# 25           85        13                 0  normal           normal
# 26           89        12                 0  normal             alta
# 27           86        12                 0  normal           normal
# 28           79        13                 0  normal           normal
# 29           83        13                 0  normal           normal
# ..          ...       ...               ...     ...              ...
# 374          95        10                 2   baixa            baixa
# 375          99        13                 2   baixa            baixa
# 376         101        13                 2   baixa            baixa
# 377         101        12                 2   baixa            baixa
# 378         102        13                 2   baixa            baixa
# 379         105        12                 2   baixa            baixa
# 380         100        12                 2   baixa            baixa
# 381          93        10                 2   baixa            baixa
# 382          93        11                 2   baixa            baixa
# 383          98        11                 2   baixa            baixa
# 384          97        10                 2   baixa             alta
# 385          98        11                 2   baixa            baixa
# 386          96        10                 2   baixa            baixa
# 387         100        13                 2   baixa            baixa
# 388         102        12                 2   baixa            baixa
# 389         100        13                 2   baixa            baixa
# 390          98        11                 2   baixa            baixa
# 391          95        10                 2   baixa            baixa
# 392          96        10                 2   baixa            baixa
# 393          95        11                 2   baixa            baixa
# 394          94        10                 2   baixa            baixa
# 395          99        13                 2   baixa            baixa
# 396          99        13                 2   baixa            baixa
# 397          95        10                 2   baixa            baixa
# 398          95        10                 2   baixa            baixa
# 399          99        26                 2   baixa             alta
# 400         100        13                 2   baixa            baixa
# 401         103        13                 2   baixa            baixa
# 402         104        26                 2   baixa            baixa
# 403         105        11                 2   baixa            baixa
#
# [404 rows x 5 columns]

# %% [markdown]
# # --------------------------------------------------------------------- #

# %% [markdown]
# # knn Teste 02

# %%
from sklearn.neighbors import KNeighborsClassifier
X_train = entradas
x_train = entradas
y_train = saidas
x_test = entradas
y_test = saidas
X = entradas
y = saidas

# %%
knn = KNeighborsClassifier(n_neighbors=3, weights='distance')
knn.fit(x_train[:404], y_train[0:404].ravel())
output = knn.predict(x_test)

# %%
a = []
y = x.size
i = 0

#print(knn.predict([x_test[200]]))
#print(y_test[200])

for i in range( 404 ):
    if output[i] == 0:
        n = "normal"
        a.append(n)
    elif output[i] == 1:
        n = "alta"
        a.append(n)
    elif output[i] == 2:
        n = "baixa"
        a.append(n)

# %%
correct = 0.0
for i in range(len(output)):
    if y_test[i] == output[i]:
        correct += 1
correct / len(output)
# Out:
# 0.905940594059406

# %% [markdown]
# # 91% de acerto, houve um aumento significativo usando essa estrutura.

# %%
dados['knn Resultado 2'] = a1
dados
# Out:
#      Batimentos  Calorias  Pressão Arterial Legenda knn Resultado 01  \
# 0            86        34                 0  normal           normal
# 1            93        34                 0  normal           normal
# 2            92        13                 0  normal           normal
# 3            94        12                 0  normal             alta
# 4            87        12                 0  normal           normal
# 5            88        12                 0  normal           normal
# 6            80        10                 0  normal           normal
# 7            84        10                 0  normal           normal
# 8            70        11                 0  normal           normal
# 9            63        11                 0  normal           normal
# 10           66        11                 0  normal           normal
# 11           69        11                 0  normal           normal
# 12           69        11                 0  normal           normal
# 13           70        10                 0  normal           normal
# 14           82        13                 0  normal           normal
# 15           84        13                 0  normal           normal
# 16           86        13                 0  normal           normal
# 17           82        13                 0  normal           normal
# 18           82        13                 0  normal           normal
# 19           85        13                 0  normal           normal
# 20           78        12                 0  normal           normal
# 21           75        12                 0  normal           normal
# 22           75        12                 0  normal           normal
# 23           78        12                 0  normal           normal
# 24           87        12                 0  normal           normal
# 25           85        13                 0  normal           normal
# 26           89        12                 0  normal             alta
# 27           86        12                 0  normal           normal
# 28           79        13                 0  normal           normal
# 29           83        13                 0  normal           normal
# ..          ...       ...               ...     ...              ...
# 374          95        10                 2   baixa            baixa
# 375          99        13                 2   baixa            baixa
# 376         101        13                 2   baixa            baixa
# 377         101        12                 2   baixa            baixa
# 378         102        13                 2   baixa            baixa
# 379         105        12                 2   baixa            baixa
# 380         100        12                 2   baixa            baixa
# 381          93        10                 2   baixa            baixa
# 382          93        11                 2   baixa            baixa
# 383          98        11                 2   baixa            baixa
# 384          97        10                 2   baixa             alta
# 385          98        11                 2   baixa            baixa
# 386          96        10                 2   baixa            baixa
# 387         100        13                 2   baixa            baixa
# 388         102        12                 2   baixa            baixa
# 389         100        13                 2   baixa            baixa
# 390          98        11                 2   baixa            baixa
# 391          95        10                 2   baixa            baixa
# 392          96        10                 2   baixa            baixa
# 393          95        11                 2   baixa            baixa
# 394          94        10                 2   baixa            baixa
# 395          99        13                 2   baixa            baixa
# 396          99        13                 2   baixa            baixa
# 397          95        10                 2   baixa            baixa
# 398          95        10                 2   baixa            baixa
# 399          99        26                 2   baixa             alta
# 400         100        13                 2   baixa            baixa
# 401         103        13                 2   baixa            baixa
# 402         104        26                 2   baixa            baixa
# 403         105        11                 2   baixa            baixa
#
#     knn Resultado 2
# 0            normal
# 1            normal
# 2            normal
# 3            normal
# 4            normal
# 5            normal
# 6            normal
# 7            normal
# 8            normal
# 9            normal
# 10           normal
# 11           normal
# 12           normal
# 13           normal
# 14           normal
# 15           normal
# 16           normal
# 17           normal
# 18           normal
# 19           normal
# 20           normal
# 21           normal
# 22           normal
# 23           normal
# 24           normal
# 25           normal
# 26           normal
# 27           normal
# 28           normal
# 29           normal
# ..              ...
# 374           baixa
# 375           baixa
# 376           baixa
# 377           baixa
# 378           baixa
# 379           baixa
# 380           baixa
# 381           baixa
# 382           baixa
# 383           baixa
# 384           baixa
# 385           baixa
# 386           baixa
# 387           baixa
# 388           baixa
# 389           baixa
# 390           baixa
# 391           baixa
# 392           baixa
# 393           baixa
# 394           baixa
# 395           baixa
# 396           baixa
# 397           baixa
# 398           baixa
# 399           baixa
# 400           baixa
# 401           baixa
# 402           baixa
# 403           baixa
#
# [404 rows x 6 columns]

# %%
def specie_color(x):
    if x == 'normal':
        return 0
    elif x == 'alta':
        return 1
    return 2

# %%
def alerta(x):
    if x == 'alta':
        print('\033[31m'+'Sua pressão parece estar muito alta, procure um médico'+'\033[40m')
    elif x == 'baixa':
        print('\033[46m'+'Sua pressão parece estar muito baixa, procure um médico'+'\033[40m')

# %%
def alerta_cuidador(x):
    if x == 'normal':
        return 0
        
    elif x == 'alta':
        return 2
        
    elif x == 'baixa':
        return 1

# %%
dados['ALERTAR CUIDADOR'] = dados['knn Resultado 2'].apply(alerta_cuidador)

# %%
dados['SpeciesNumber'] = dados['knn Resultado 2'].apply(specie_color)

# %%
dados
# Out:
#      Batimentos  Calorias  Pressão Arterial Legenda knn Resultado 01  \
# 0            86        34                 0  normal           normal
# 1            93        34                 0  normal           normal
# 2            92        13                 0  normal           normal
# 3            94        12                 0  normal             alta
# 4            87        12                 0  normal           normal
# 5            88        12                 0  normal           normal
# 6            80        10                 0  normal           normal
# 7            84        10                 0  normal           normal
# 8            70        11                 0  normal           normal
# 9            63        11                 0  normal           normal
# 10           66        11                 0  normal           normal
# 11           69        11                 0  normal           normal
# 12           69        11                 0  normal           normal
# 13           70        10                 0  normal           normal
# 14           82        13                 0  normal           normal
# 15           84        13                 0  normal           normal
# 16           86        13                 0  normal           normal
# 17           82        13                 0  normal           normal
# 18           82        13                 0  normal           normal
# 19           85        13                 0  normal           normal
# 20           78        12                 0  normal           normal
# 21           75        12                 0  normal           normal
# 22           75        12                 0  normal           normal
# 23           78        12                 0  normal           normal
# 24           87        12                 0  normal           normal
# 25           85        13                 0  normal           normal
# 26           89        12                 0  normal             alta
# 27           86        12                 0  normal           normal
# 28           79        13                 0  normal           normal
# 29           83        13                 0  normal           normal
# ..          ...       ...               ...     ...              ...
# 374          95        10                 2   baixa            baixa
# 375          99        13                 2   baixa            baixa
# 376         101        13                 2   baixa            baixa
# 377         101        12                 2   baixa            baixa
# 378         102        13                 2   baixa            baixa
# 379         105        12                 2   baixa            baixa
# 380         100        12                 2   baixa            baixa
# 381          93        10                 2   baixa            baixa
# 382          93        11                 2   baixa            baixa
# 383          98        11                 2   baixa            baixa
# 384          97        10                 2   baixa             alta
# 385          98        11                 2   baixa            baixa
# 386          96        10                 2   baixa            baixa
# 387         100        13                 2   baixa            baixa
# 388         102        12                 2   baixa            baixa
# 389         100        13                 2   baixa            baixa
# 390          98        11                 2   baixa            baixa
# 391          95        10                 2   baixa            baixa
# 392          96        10                 2   baixa            baixa
# 393          95        11                 2   baixa            baixa
# 394          94        10                 2   baixa            baixa
# 395          99        13                 2   baixa            baixa
# 396          99        13                 2   baixa            baixa
# 397          95        10                 2   baixa            baixa
# 398          95        10                 2   baixa            baixa
# 399          99        26                 2   baixa             alta
# 400         100        13                 2   baixa            baixa
# 401         103        13                 2   baixa            baixa
# 402         104        26                 2   baixa            baixa
# 403         105        11                 2   baixa            baixa
#
#     knn Resultado 2  ALERTAR CUIDADOR  SpeciesNumber
# 0            normal                 0              0
# 1            normal                 0              0
# 2            normal                 0              0
# 3            normal                 0              0
# 4            normal                 0              0
# 5            normal                 0              0
# 6            normal                 0              0
# 7            normal                 0              0
# 8            normal                 0              0
# 9            normal                 0              0
# 10           normal                 0              0
# 11           normal                 0              0
# 12           normal                 0              0
# 13           normal                 0              0
# 14           normal                 0              0
# 15           normal                 0              0
# 16           normal                 0              0
# 17           normal                 0              0
# 18           normal                 0              0
# 19           normal                 0              0
# 20           normal                 0              0
# 21           normal                 0              0
# 22           normal                 0              0
# 23           normal                 0              0
# 24           normal                 0              0
# 25           normal                 0              0
# 26           normal                 0              0
# 27           normal                 0              0
# 28           normal                 0              0
# 29           normal                 0              0
# ..              ...               ...            ...
# 374           baixa                 1              2
# 375           baixa                 1              2
# 376           baixa                 1              2
# 377           baixa                 1              2
# 378           baixa                 1              2
# 379           baixa                 1              2
# 380           baixa                 1              2
# 381           baixa                 1              2
# 382           baixa                 1              2
# 383           baixa                 1              2
# 384           baixa                 1              2
# 385           baixa                 1              2
# 386           baixa                 1              2
# 387           baixa                 1              2
# 388           baixa                 1              2
# 389           baixa                 1              2
# 390           baixa                 1              2
# 391           baixa                 1              2
# 392           baixa                 1              2
# 393           baixa                 1              2
# 394           baixa                 1              2
# 395           baixa                 1              2
# 396           baixa                 1              2
# 397           baixa                 1              2
# 398           baixa                 1              2
# 399           baixa                 1              2
# 400           baixa                 1              2
# 401           baixa                 1              2
# 402           baixa                 1              2
# 403           baixa                 1              2
#
# [404 rows x 8 columns]

# %%
plt.scatter(
    dados['Batimentos'], dados['Calorias'], marker='o', sizes=0.8 * dados['Batimentos'],
    c=dados['SpeciesNumber'], cmap='plasma_r', alpha=0.4
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.externals import joblib

# %%
joblib.dump(knn, 'analytics_folder/knn.pkl')
# Out:
# ['analytics_folder/knn.pkl']

# %%
import pickle as pickle

# %%
pickle.dump(knn, open('analytics_folder/knn.pkl', 'wb'))

# %%
my_knn = pickle.load(open('analytics_folder/knn.pkl', 'rb'))

# %%
my_knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='distance')

# %%
import requests, json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-0385a0ab8f7b> in <module>()
# ----> 1 import requests, json
#
# ModuleNotFoundError: No module named 'requests'

# %%
def legenda(m):
    if m['results'] == '0.0':
        return 0
        
    elif m['results'] == '1.0':
        return 2
        
    elif m['results'] == '2.0':
        return 1

# %%
url = "http://localhost:9000/api"
data = json.dumps({'Batimentos':98,'Calorias':55})
lista_resultados = []
r = requests.post(url, data)
m = r.json()

m = m['results'][0]

# %%
def resultado_knn():
    if m == 0.0:
        print('NORMAL')
    
    elif m == 1.0:
        print('BAIXA')
        
    elif m == 2.0:
        print('ALTA')
    

resultado_knn()
